# %%
from kafka import KafkaConsumer
from kafka import TopicPartition
from kafka import KafkaProducer
from kafka.structs import OffsetAndMetadata
import json
import requests

# %%
topic = TopicPartition('twitter', 0)
consumer = KafkaConsumer(bootstrap_servers='localhost:9092')
consumer.assign([topic])
for msg in consumer:
    row = eval(msg.value)
    print row
# Out:
# {'timestamp': 1239056385000000000, 'message': "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D", 'nickname': '_TheSpecialOne_', 'request': 'NO_QUERY', 'UID': '4873ec6179bc4df293cf174ee7974b6e'}
# {'timestamp': 1239056389000000000, 'message': "is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 'nickname': 'scotthamilton', 'request': 'NO_QUERY', 'UID': '3524433347534c8db764ac7d86d0d0d8'}
# {'timestamp': 1239056393000000000, 'message': '@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds', 'nickname': 'mattycus', 'request': 'NO_QUERY', 'UID': 'f85996f459ab4eb98ed3a104c22501d9'}
# {'timestamp': 1239056397000000000, 'message': 'my whole body feels itchy and like its on fire ', 'nickname': 'ElleCTF', 'request': 'NO_QUERY', 'UID': '7f19cbb41d55494199f571d29f030039'}
# {'timestamp': 1239056397000000000, 'message': "@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there. ", 'nickname': 'Karoli', 'request': 'NO_QUERY', 'UID': '0df92c2562e54a2687d6fd2df53f4ea7'}
# {'timestamp': 1239056400000000000, 'message': '@Kwesidei not the whole crew ', 'nickname': 'joy_wolf', 'request': 'NO_QUERY', 'UID': '2da1af7e27674fc5bd0f5a5e56efde4f'}
# {'timestamp': 1239056403000000000, 'message': 'Need a hug ', 'nickname': 'mybirch', 'request': 'NO_QUERY', 'UID': '4830a9a25fca491aa49a1e3a1e609a60'}
# {'timestamp': 1239056403000000000, 'message': "@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?", 'nickname': 'coZZ', 'request': 'NO_QUERY', 'UID': '8ff99729ad7e4ca4a0817d74353eaf8b'}
# {'timestamp': 1239056405000000000, 'message': "@Tatiana_K nope they didn't have it ", 'nickname': '2Hood4Hollywood', 'request': 'NO_QUERY', 'UID': '439ca5739a1e45728a3f84fe3454219d'}
# {'timestamp': 1239056409000000000, 'message': '@twittera que me muera ? ', 'nickname': 'mimismo', 'request': 'NO_QUERY', 'UID': 'a7a3a4af8da4414a9c977056ca6958fe'}
# {'timestamp': 1239056416000000000, 'message': "spring break in plain city... it's snowing ", 'nickname': 'erinx3leannexo', 'request': 'NO_QUERY', 'UID': '3a4be12ad9474d1189919ee96a1bbd35'}
# {'timestamp': 1239056417000000000, 'message': 'I just re-pierced my ears ', 'nickname': 'pardonlauren', 'request': 'NO_QUERY', 'UID': 'a4fe8a745264400f9accab90c309b8d5'}
# {'timestamp': 1239056419000000000, 'message': "@caregiving I couldn't bear to watch it.  And I thought the UA loss was embarrassing . . . . .", 'nickname': 'TLeC', 'request': 'NO_QUERY', 'UID': 'ac683a61e8af4deca19f6754913a1234'}
# {'timestamp': 1239056419000000000, 'message': '@octolinz16 It it counts, idk why I did either. you never talk to me anymore ', 'nickname': 'robrobbierobert', 'request': 'NO_QUERY', 'UID': 'edea39880a364e49862f7a01eda3e1c7'}
# {'timestamp': 1239056420000000000, 'message': "@smarrison i would've been the first, but i didn't have a gun.    not really though, zac snyder's just a doucheclown.", 'nickname': 'bayofwolves', 'request': 'NO_QUERY', 'UID': 'ba5135183fa24281a29d0d985aa05801'}
# {'timestamp': 1239056420000000000, 'message': '@iamjazzyfizzle I wish I got to watch it with you!! I miss you and @iamlilnicki  how was the premiere?!', 'nickname': 'HairByJess', 'request': 'NO_QUERY', 'UID': 'e70e7cfdb62d4e6cb2eb04281241717b'}
# {'timestamp': 1239056422000000000, 'message': "Hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?", 'nickname': 'lovesongwriter', 'request': 'NO_QUERY', 'UID': 'a0e57631e943453a88cb35d3febe8ce1'}
# {'timestamp': 1239056425000000000, 'message': 'about to file taxes ', 'nickname': 'armotley', 'request': 'NO_QUERY', 'UID': 'aa0caa115aea473b8cf367fd6a58b7ea'}
# {'timestamp': 1239056431000000000, 'message': '@LettyA ahh ive always wanted to see rent  love the soundtrack!!', 'nickname': 'starkissed', 'request': 'NO_QUERY', 'UID': '6e9d1c17b01046e79a6b42d6c79ab28c'}
# {'timestamp': 1239056434000000000, 'message': '@FakerPattyPattz Oh dear. Were you drinking out of the forgotten table drinks? ', 'nickname': 'gi_gi_bee', 'request': 'NO_QUERY', 'UID': 'edca86337f274a5ba906b6497bc302c7'}
# {'timestamp': 1239056437000000000, 'message': "@alydesigns i was out most of the day so didn't get much done ", 'nickname': 'quanvu', 'request': 'NO_QUERY', 'UID': '854b32dd4579444aa7e00b6e0649b7b9'}
# {'timestamp': 1239056438000000000, 'message': "one of my friend called me, and asked to meet with her at Mid Valley today...but i've no time *sigh* ", 'nickname': 'swinspeedx', 'request': 'NO_QUERY', 'UID': '32014c028fca4e2284c9be7cb20c9c0f'}
# {'timestamp': 1239056440000000000, 'message': '@angry_barista I baked you a cake but I ated it ', 'nickname': 'cooliodoc', 'request': 'NO_QUERY', 'UID': '9cf5e9ac37504e85a9afe5a667620eea'}
# {'timestamp': 1239056440000000000, 'message': 'this week is not going as i had hoped ', 'nickname': 'viJILLante', 'request': 'NO_QUERY', 'UID': '26b8005453644454a42318e2b3d17af8'}
# {'timestamp': 1239056441000000000, 'message': 'blagh class at 8 tomorrow ', 'nickname': 'Ljelli3166', 'request': 'NO_QUERY', 'UID': 'a18e2b914d2c43dc86e7d0a9c3616887'}
# {'timestamp': 1239056444000000000, 'message': 'I hate when I have to call and wake people up ', 'nickname': 'ChicagoCubbie', 'request': 'NO_QUERY', 'UID': 'a80af2189f7b42f39aa56819ccb46672'}
# {'timestamp': 1239056450000000000, 'message': 'Just going to cry myself to sleep after watching Marley and Me.  ', 'nickname': 'KatieAngell', 'request': 'NO_QUERY', 'UID': 'd26dd06efc764983b8c7acfccd1f1b11'}
# {'timestamp': 1239056452000000000, 'message': 'im sad now  Miss.Lilly', 'nickname': 'gagoo', 'request': 'NO_QUERY', 'UID': 'f41d47b3730440d083f386da33fae674'}
# {'timestamp': 1239056456000000000, 'message': "ooooh.... LOL  that leslie.... and ok I won't do it again so leslie won't  get mad again ", 'nickname': 'abel209', 'request': 'NO_QUERY', 'UID': 'c6b0c3349d624c949c968499dff81094'}
# {'timestamp': 1239056464000000000, 'message': 'Meh... Almost Lover is the exception... this track gets me depressed every time. ', 'nickname': 'BaptisteTheFool', 'request': 'NO_QUERY', 'UID': 'fba604252322421f9a34010b24ec565a'}
# {'timestamp': 1239056467000000000, 'message': 'some1 hacked my account on aim  now i have to make a new one', 'nickname': 'fatkat309', 'request': 'NO_QUERY', 'UID': '670153b2bff54af386ff6284a8cc2f61'}
# {'timestamp': 1239056467000000000, 'message': '@alielayus I want to go to promote GEAR AND GROOVE but unfornately no ride there  I may b going to the one in Anaheim in May though', 'nickname': 'EmCDL', 'request': 'NO_QUERY', 'UID': '0b12c3c58f4a4b1487df1dd916d490ff'}
# {'timestamp': 1239056469000000000, 'message': 'thought sleeping in was an option tomorrow but realizing that it now is not. evaluations in the morning and work in the afternoon! ', 'nickname': 'merisssa', 'request': 'NO_QUERY', 'UID': 'a294493590014b7a9210d92973461903'}
# {'timestamp': 1239056471000000000, 'message': '@julieebaby awe i love you too!!!! 1 am here  i miss you', 'nickname': 'Pbearfox', 'request': 'NO_QUERY', 'UID': 'bdf01e62471e438786951bdfd129ab06'}
# {'timestamp': 1239056481000000000, 'message': '@HumpNinja I cry my asian eyes to sleep at night ', 'nickname': 'jsoo', 'request': 'NO_QUERY', 'UID': 'a9352f09985d4c328b1fc31e7aacf5cf'}
# {'timestamp': 1239056480000000000, 'message': "ok I'm sick and spent an hour sitting in the shower cause I was too sick to stand and held back the puke like a champ. BED now ", 'nickname': 'scarletletterm', 'request': 'NO_QUERY', 'UID': '42da9060383348b187a835a0237b043f'}
# {'timestamp': 1239056487000000000, 'message': '@cocomix04 ill tell ya the story later  not a good day and ill be workin for like three more hours...', 'nickname': 'crosland_12', 'request': 'NO_QUERY', 'UID': 'dbed53b36ace48129f806c9d5091a706'}
# {'timestamp': 1239056490000000000, 'message': '@MissXu sorry! bed time came here (GMT+1)   http://is.gd/fNge', 'nickname': 'ajaxpro', 'request': 'NO_QUERY', 'UID': 'df1d94c27c0d4a6dabef0e79e0e43fd3'}
# {'timestamp': 1239056492000000000, 'message': "@fleurylis I don't either. Its depressing. I don't think I even want to know about the kids in suitcases. ", 'nickname': 'Tmttq86', 'request': 'NO_QUERY', 'UID': '61ce69480b1e48b99841a6b33df96f47'}
# {'timestamp': 1239056499000000000, 'message': "Bed. Class 8-12. Work 12-3. Gym 3-5 or 6. Then class 6-10. Another day that's gonna fly by. I miss my girlfriend ", 'nickname': 'Anthony_Nguyen', 'request': 'NO_QUERY', 'UID': 'c5b9ebb45276492eab2e0a2297a09a5c'}
# {'timestamp': 1239056499000000000, 'message': "really don't feel like getting up today... but got to study to for tomorrows practical exam... ", 'nickname': 'itsanimesh', 'request': 'NO_QUERY', 'UID': '97032c69dea644a885e1ecb06e2de93a'}
# {'timestamp': 1239056506000000000, 'message': "He's the reason for the teardrops on my guitar the only one who has enough of me to break my heart ", 'nickname': 'lionslamb', 'request': 'NO_QUERY', 'UID': '2f890231d1b54b8c959fa1e1147950ef'}
# {'timestamp': 1239056509000000000, 'message': "Sad, sad, sad. I don't know why but I hate this feeling  I wanna sleep and I still can't!", 'nickname': 'kennypham', 'request': 'NO_QUERY', 'UID': 'bcdafa524e6c4f9f875b538ceda0b0f7'}
# {'timestamp': 1239056513000000000, 'message': '@JonathanRKnight Awww I soo wish I was there to see you finally comfortable! Im sad that I missed it ', 'nickname': 'DdubsShellBell', 'request': 'NO_QUERY', 'UID': '67579918e3ca4de88e5b0b2f6c23c0b1'}
# {'timestamp': 1239056516000000000, 'message': "Falling asleep. Just heard about that Tracy girl's body being found. How sad  My heart breaks for that family.", 'nickname': 'hpfangirl94', 'request': 'NO_QUERY', 'UID': '32ce0c83fe1041f782d0aedc8b7b0ec1'}
# {'timestamp': 1239056525000000000, 'message': "@Viennah Yay! I'm happy for you with your job! But that also means less time for me and you... ", 'nickname': 'antzpantz', 'request': 'NO_QUERY', 'UID': 'bb02f63dd8cb4bda8fa2cee84105158a'}
# {'timestamp': 1239056526000000000, 'message': 'Just checked my user timeline on my blackberry, it looks like the twanking is still happening  Are ppl still having probs w/ BGs and UIDs?', 'nickname': 'labrt2004', 'request': 'NO_QUERY', 'UID': '402749e7bc8a4ae2bd44d78e7f96f02f'}
# {'timestamp': 1239056527000000000, 'message': "Oh man...was ironing @jeancjumbe's fave top to wear to a meeting. Burnt it ", 'nickname': 'IrisJumbe', 'request': 'NO_QUERY', 'UID': '5f49f79f28b94de28a71d17c52a5716a'}
# {'timestamp': 1239056533000000000, 'message': 'is strangely sad about LiLo and SamRo breaking up. ', 'nickname': 'peacoats', 'request': 'NO_QUERY', 'UID': '33c03221d9224632812764802411d48d'}
# {'timestamp': 1239056545000000000, 'message': "@tea oh! i'm so sorry  i didn't think about that before retweeting.", 'nickname': 'cyantist', 'request': 'NO_QUERY', 'UID': '8b4bd6d727994839bc9c0fce2e5c40f9'}
# {'timestamp': 1239056543000000000, 'message': "Broadband plan 'a massive broken promise' http://tinyurl.com/dcuc33 via www.diigo.com/~tautao Still waiting for broadband we are ", 'nickname': 'tautao', 'request': 'NO_QUERY', 'UID': 'b52986defb7c4893b671032ecc22eda3'}
# {'timestamp': 1239056544000000000, 'message': "@localtweeps Wow, tons of replies from you, may have to unfollow so I can see my friends' tweets, you're scrolling the feed a lot. ", 'nickname': 'voyage2k', 'request': 'NO_QUERY', 'UID': '8048fb0906f3467cae2872e1be1a9b02'}
# {'timestamp': 1239056546000000000, 'message': 'our duck and chicken are taking wayyy too long to hatch ', 'nickname': 'crzy_cdn_bulas', 'request': 'NO_QUERY', 'UID': 'd5fe4c136c9444acb76b93db7c2cf6d5'}
# {'timestamp': 1239056550000000000, 'message': 'Put vacation photos online a few yrs ago. PC crashed, and now I forget the name of the site. ', 'nickname': 'justnetgirl', 'request': 'NO_QUERY', 'UID': '8b32c2fa082449eea004ee8e753fcd5b'}
# {'timestamp': 1239056552000000000, 'message': 'I need a hug ', 'nickname': 'CiaraRenee', 'request': 'NO_QUERY', 'UID': '1256313569474640be48c2ef674b7e36'}
# {'timestamp': 1239056557000000000, 'message': '@andywana Not sure what they are, only that they are PoS! As much as I want to, I dont think can trade away company assets sorry andy! ', 'nickname': 'deelau', 'request': 'NO_QUERY', 'UID': '256ce56234ee4640bf8f545f6a3c5648'}
# {'timestamp': 1239056567000000000, 'message': '@oanhLove I hate when that happens... ', 'nickname': 'Lindsey0920', 'request': 'NO_QUERY', 'UID': '43372a6d73a644f88f7f8360549e2b1d'}
# {'timestamp': 1239056567000000000, 'message': "I have a sad feeling that Dallas is not going to show up  I gotta say though, you'd think more shows would use music from the game. mmm", 'nickname': 'HybridMink', 'request': 'NO_QUERY', 'UID': 'dd45ae551553414c94880dee2e7da2fd'}
# {'timestamp': 1239056569000000000, 'message': 'Ugh....92 degrees tomorrow ', 'nickname': 'gzacher', 'request': 'NO_QUERY', 'UID': 'dbaee4d094b14a9f8c51fce1c750e1d0'}
# {'timestamp': 1239056569000000000, 'message': 'Where did u move to?  I thought u were already in sd. ?? Hmmm. Random u found me. Glad to hear yer doing well.', 'nickname': 'Jenn_L', 'request': 'NO_QUERY', 'UID': '17047c707a2446639b53328433e515ed'}
# {'timestamp': 1239056572000000000, 'message': "@BatManYNG I miss my ps3, it's out of commission  Wutcha playing? Have you copped 'Blood On The Sand'?", 'nickname': 'xVivaLaJuicyx', 'request': 'NO_QUERY', 'UID': '00ab8c2bdbbd48d89d29d6e060e0c96b'}
# {'timestamp': 1239056575000000000, 'message': 'just leaving the parking lot of work! ', 'nickname': 'krbleyle', 'request': 'NO_QUERY', 'UID': '2c82a2b1057944a8b910aa11960deaff'}
# {'timestamp': 1239056583000000000, 'message': 'The Life is cool. But not for Me. ', 'nickname': 'xpika', 'request': 'NO_QUERY', 'UID': 'f43fd90af2f3406cb076703fd0150be2'}
# {'timestamp': 1239056588000000000, 'message': "Sadly though, I've never gotten to experience the post coitus cigarette before, and now I never will. ", 'nickname': 'Henkuyinepu', 'request': 'NO_QUERY', 'UID': '773f0e5c9e4a4e85a29d1f350062a2b5'}
# {'timestamp': 1239056589000000000, 'message': 'I had such a nice day. Too bad the rain comes in tomorrow at 5am ', 'nickname': 'ericg622', 'request': 'NO_QUERY', 'UID': '415a750102994717a470e1a44d09a5e2'}
# {'timestamp': 1239056595000000000, 'message': "@Starrbby too bad I won't be around I lost my job and can't even pay my phone bill lmao aw shucks ", 'nickname': 'adri_mane', 'request': 'NO_QUERY', 'UID': '2188ac0d179b4c99bdad06705e79062f'}
# {'timestamp': 1239056603000000000, 'message': 'Damm back to school tomorrow ', 'nickname': 'a_mariepyt', 'request': 'NO_QUERY', 'UID': '9f23164458b043a78bbb69779cd24c2a'}
# {'timestamp': 1239056608000000000, 'message': "Mo jobs, no money.  how in the hell is min wage here 4 f'n clams an hour?", 'nickname': 'playboybacon', 'request': 'NO_QUERY', 'UID': '98774c470fd647d2b3adffc08b2c9371'}
# {'timestamp': 1239056608000000000, 'message': '@katortiz  Not forever... See you soon!', 'nickname': 'leslierosales', 'request': 'NO_QUERY', 'UID': '7f9aef9b0e3642899d5c443b5153d9e5'}
# {'timestamp': 1239056610000000000, 'message': '@Lt_Algonquin agreed, I saw the failwhale allllll day today. ', 'nickname': 'PresidentSnow', 'request': 'NO_QUERY', 'UID': '15d9eef043da436ab343ed3ace37cc9d'}
# {'timestamp': 1239056615000000000, 'message': "@jdarter Oh! Haha... dude I dont really look at em unless someone says HEY I ADDED YOU. Sorry  I'm so terrible at that. I need a pop up!", 'nickname': 'michrod', 'request': 'NO_QUERY', 'UID': '8b7a87c1af994a21ac5575d710dbd016'}
# {'timestamp': 1239056619000000000, 'message': "@ninjen I'm sure you're right...    I need to start working out with you and the Nikster... Or Jared at least!", 'nickname': 'timmelko', 'request': 'NO_QUERY', 'UID': '8388511df88e405b8b6faff9959dcc0f'}
# {'timestamp': 1239056623000000000, 'message': 'i really hate how people diss my bands!  Trace is clearly NOT ugly!', 'nickname': 'BrookeAmanda', 'request': 'NO_QUERY', 'UID': 'dccde997307149beb8bb040c42681ac7'}
# {'timestamp': 1239056623000000000, 'message': 'Gym attire today was: Puma singlet, Adidas shorts.......and black business socks and leather shoes  Lucky did not run into any cute girls.', 'nickname': 'deelau', 'request': 'NO_QUERY', 'UID': 'b69f4f7609b4454c813cb00ca41dccf7'}
# {'timestamp': 1239056625000000000, 'message': "Why won't you show my location?!   http://twitpic.com/2y2es", 'nickname': 'paulseverio', 'request': 'NO_QUERY', 'UID': 'ac26667054da4468bbc7df53af1699fd'}
# {'timestamp': 1239056744000000000, 'message': 'No picnic  my phone smells like citrus.', 'nickname': 'iv3tte', 'request': 'NO_QUERY', 'UID': '4ee63abb1dba4f0b89b0a5699fb19ea4'}
# {'timestamp': 1239056744000000000, 'message': "@ashleyac My donkey is sensitive about such comments. Nevertheless, he'd (and me'd) be glad to see your mug asap. Charger is still awol. ", 'nickname': 'fedunska', 'request': 'NO_QUERY', 'UID': '075f68e4939c41e6b77db9340da3568a'}
# {'timestamp': 1239056745000000000, 'message': 'No new csi tonight.  FML', 'nickname': 'MagicalMason', 'request': 'NO_QUERY', 'UID': 'bcf4cfee003d4e0d87a34c9d40934cfd'}
# {'timestamp': 1239056746000000000, 'message': 'i think my arms are sore from tennis ', 'nickname': 'kaelaaa', 'request': 'NO_QUERY', 'UID': '354514618ed349b5a49038126ad56d9b'}
# {'timestamp': 1239056749000000000, 'message': 'wonders why someone that u like so much can make you so unhappy in a split seccond . depressed . ', 'nickname': 'emo_holic', 'request': 'NO_QUERY', 'UID': '71fe3984e9fd4c35a538470fd16a6ee6'}
# {'timestamp': 1239056752000000000, 'message': 'sleep soon... i just hate saying bye and see you tomorrow for the night. ', 'nickname': 'thelazyboy', 'request': 'NO_QUERY', 'UID': '1f484b8bbf3f4305a0e6addaf1aefcd1'}
# {'timestamp': 1239056753000000000, 'message': '@statravelAU just got ur newsletter, those fares really are unbelievable, shame I already booked and paid for mine ', 'nickname': 'driveaway2008', 'request': 'NO_QUERY', 'UID': '6ee8787626564a6ebb379c2f5d4e0a0d'}
# {'timestamp': 1239056753000000000, 'message': "missin' the boo ", 'nickname': 'mscha', 'request': 'NO_QUERY', 'UID': '6a981c9806b34ea89aa9426e9990414f'}
# {'timestamp': 1239056754000000000, 'message': '@markhardy1974 Me too  #itm', 'nickname': 'mike_webster_au', 'request': 'NO_QUERY', 'UID': '786de1b6dd664f1a9f60def0e0d9bdf3'}
# {'timestamp': 1239056754000000000, 'message': "Damn... I don't have any chalk! MY CHALKBOARD IS USELESS ", 'nickname': 'basiabeans', 'request': 'NO_QUERY', 'UID': '904735bea48545fcb874c8b909e1fce6'}
# {'timestamp': 1239056756000000000, 'message': "had a blast at the Getty Villa, but hates that she's had a sore throat all day. It's just getting worse too ", 'nickname': 'calihonda2001', 'request': 'NO_QUERY', 'UID': '872c3ee44bd6445199d2e9bf4435f4e2'}
# {'timestamp': 1239056762000000000, 'message': '@msdrama hey missed ya at the meeting  sup mama', 'nickname': 'djwayneski', 'request': 'NO_QUERY', 'UID': 'a3a2d9655fc24930ae13dfe00c4314f9'}
# {'timestamp': 1239056766000000000, 'message': "My tummy hurts.  I wonder if the hypnosis has anything to do with it? If so, it's working, I get it, STOP SMOKING!!!", 'nickname': 'Ceejison', 'request': 'NO_QUERY', 'UID': '265f95701de64fb2871c1272373a3c8c'}
# {'timestamp': 1239056768000000000, 'message': 'why is it always the fat ones?! ', 'nickname': 'ItsBrigittaYo', 'request': 'NO_QUERY', 'UID': 'c7075dca0299413fb00fc8625e6fcc59'}
# {'timestamp': 1239056770000000000, 'message': "@januarycrimson Sorry, babe!!  My fam annoys me too. Thankfully, they're asleep right now. Muahaha. *evil laugh*", 'nickname': 'MissLaura317', 'request': 'NO_QUERY', 'UID': 'c0f133ea1cbb4eb884f65be6e13aba16'}
# {'timestamp': 1239056770000000000, 'message': '@Hollywoodheat I should have paid more attention when we covered photoshop in my webpage design class in undergrad ', 'nickname': 'RU_it_girl', 'request': 'NO_QUERY', 'UID': '5b198ca6dc6243fda51f93ca4652c95c'}
# {'timestamp': 1239056774000000000, 'message': "wednesday my b-day! don't know what 2 do!! ", 'nickname': 'viviana09', 'request': 'NO_QUERY', 'UID': '0a435d8b1ccb4dfc8602037b41a6bcc2'}
# {'timestamp': 1239056778000000000, 'message': 'Poor cameron (the hills) ', 'nickname': 'disneyfan4eva', 'request': 'NO_QUERY', 'UID': 'b351d4dbce9a4c0ea4884cd9658ff7a5'}
# {'timestamp': 1239056781000000000, 'message': 'pray for me please, the ex is threatening to start sh** at my/our babies 1st Birthday party. what a jerk. and I still have a headache ', 'nickname': 'RoseMaryK', 'request': 'NO_QUERY', 'UID': '2db74728ae8d4b2f9c0b5aa9ed892f12'}
# {'timestamp': 1239056782000000000, 'message': '@makeherfamous hmm  , do u really enjoy being with him ? if the problems are too constants u should think things more , find someone ulike', 'nickname': 'perrohunter', 'request': 'NO_QUERY', 'UID': '19d22e69990546c6bc536fac871cd825'}
# {'timestamp': 1239056787000000000, 'message': 'Strider is a sick little puppy  http://apps.facebook.com/dogbook/profile/view/5248435', 'nickname': 'Dogbook', 'request': 'NO_QUERY', 'UID': '6ab1bc1a55964145b0328daafa708c9d'}
# {'timestamp': 1239056788000000000, 'message': "so rylee,grace...wana go steve's party or not?? SADLY SINCE ITS EASTER I WNT B ABLE 2 DO MUCH  BUT OHH WELL.....", 'nickname': 'natalieantipas', 'request': 'NO_QUERY', 'UID': '3ba741183fee4bcaab03578641a1f43e'}
# {'timestamp': 1239056789000000000, 'message': "hey, I actually won one of my bracket pools! Too bad it wasn't the one for money ", 'nickname': 'timdonnelly', 'request': 'NO_QUERY', 'UID': 'dd45a291810644c89eb2cbbc7d9e2caa'}
# {'timestamp': 1239056789000000000, 'message': "@stark YOU don't follow me, either  and i work for you!", 'nickname': 'homeworld', 'request': 'NO_QUERY', 'UID': 'd41db9c5a1554d63861e4687acc6b513'}
# {'timestamp': 1239056793000000000, 'message': 'A bad nite for the favorite teams: Astros and Spartans lose.  The nite out with T.W. was good.', 'nickname': 'willy_chaz', 'request': 'NO_QUERY', 'UID': 'f0855bb1aaf144ff8b31550986f4fb24'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1a2123e018a4> in <module>()
#       2 consumer = KafkaConsumer(bootstrap_servers='localhost:9092')
#       3 consumer.assign([topic])
# ----> 4 for msg in consumer:
#       5     row = eval(msg.value)
#       6     print row
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/vendor/six.pyc in next(self)
#     559
#     560         def next(self):
# --> 561             return type(self).__next__(self)
#     562
#     563     callable = callable
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/consumer/group.pyc in __next__(self)
#    1116         self._set_consumer_timeout()
#    1117         try:
# -> 1118             return next(self._iterator)
#    1119         except StopIteration:
#    1120             self._iterator = None
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/consumer/group.pyc in _message_generator(self)
#    1060             if not self._fetcher.in_flight_fetches():
#    1061                 poll_ms = min(poll_ms, self.config['reconnect_backoff_ms'])
# -> 1062             self._client.poll(timeout_ms=poll_ms)
#    1063
#    1064             # after the long poll, we should check whether the group needs to rebalance
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/client_async.pyc in poll(self, timeout_ms, future)
#     554                     timeout = max(0, timeout / 1000)  # avoid negative timeouts
#     555
# --> 556                 self._poll(timeout)
#     557
#     558             # called without the lock to avoid deadlock potential
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/client_async.pyc in _poll(self, timeout)
#     572
#     573         start_select = time.time()
# --> 574         ready = self._selector.select(timeout)
#     575         end_select = time.time()
#     576         if self._sensors:
#
# /Users/bastienbrunod/anaconda2/lib/python2.7/site-packages/kafka/vendor/selectors34.pyc in select(self, timeout)
#     598             ready = []
#     599             try:
# --> 600                 kev_list = self._kqueue.control(None, max_ev, timeout)
#     601             except OSError as exc:
#     602                 if exc.errno == EINTR:
#
# KeyboardInterrupt:
